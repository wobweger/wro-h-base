# %%
import pandas as pd
import numpy as np

# %%
oDat= pd.read_csv("x_dat/sensor_df.csv.gz", encoding = "ISO-8859-1")

# %%
oDat2= pd.read_csv("x_dat/datatest2.txt.gz", encoding = "ISO-8859-1")

# %%
oDat.head(5)
# Out:
#           Timestamp  ID   RSS_anchor2   RSS_anchor3   RSS_anchor4
# 0  01-01-2012 00:00   1         -0.48       0.28571          0.30
# 1  01-01-2012 00:10   1         -0.32       0.14286          0.30
# 2  01-01-2012 00:20   1         -0.28      -0.14286          0.35
# 3  01-01-2012 00:30   1         -0.20      -0.47619          0.35
# 4  01-01-2012 00:40   1         -0.20       0.14286         -0.20

# %%
oDat2.head(5)
# Out:
#                   date  Temperature   Humidity       Light          CO2  \
# 1  2015-02-11 14:48:00      21.7600  31.133333  437.333333  1029.666667
# 2  2015-02-11 14:49:00      21.7900  31.000000  437.333333  1000.000000
# 3  2015-02-11 14:50:00      21.7675  31.122500  434.000000  1003.750000
# 4  2015-02-11 14:51:00      21.7675  31.122500  439.000000  1009.500000
# 5  2015-02-11 14:51:59      21.7900  31.133333  437.333333  1005.666667
#
#    HumidityRatio  Occupancy
# 1       0.005021          1
# 2       0.005009          1
# 3       0.005022          1
# 4       0.005022          1
# 5       0.005030          1

# %%
oDat1= pd.read_csv("x_dat/datatraining.txt.gz", encoding = "ISO-8859-1")

# %%
oDat1.head(5)
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
oD=pd.concat([oDat1,oDat2])

# %%
oD['datetime'] = pd.to_datetime(oD['date'])
oD = oD.set_index('datetime')
oD.drop(['date'], axis=1, inplace=True)

# %%
oD['2015-02-05']
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# datetime
# 2015-02-05 00:00:00    21.245000   25.2450    0.0  456.500000       0.003938
# 2015-02-05 00:01:00    21.245000   25.2450    0.0  458.500000       0.003938
# 2015-02-05 00:02:00    21.260000   25.2600    0.0  459.666667       0.003944
# 2015-02-05 00:03:00    21.245000   25.2450    0.0  464.000000       0.003938
# 2015-02-05 00:04:00    21.245000   25.2000    0.0  465.000000       0.003931
# 2015-02-05 00:04:59    21.290000   25.2000    0.0  461.000000       0.003942
# 2015-02-05 00:06:00    21.245000   25.2000    0.0  458.500000       0.003931
# 2015-02-05 00:07:00    21.290000   25.2000    0.0  459.000000       0.003942
# 2015-02-05 00:08:00    21.290000   25.2000    0.0  451.000000       0.003942
# 2015-02-05 00:08:59    21.290000   25.2000    0.0  456.000000       0.003942
# 2015-02-05 00:10:00    21.290000   25.2000    0.0  463.000000       0.003942
# ...

# %%
   oD[oD.index.hour==4]
# Out:
#                      Temperature   Humidity  Light          CO2  \
# datetime
# 2015-02-05 04:00:00    21.000000  24.390000    0.0   442.000000
# 2015-02-05 04:01:00    21.000000  24.356667    0.0   442.666667
# 2015-02-05 04:01:59    21.000000  24.290000    0.0   439.000000
# 2015-02-05 04:02:59    20.890000  24.390000    0.0   440.000000
# 2015-02-05 04:04:00    20.945000  24.390000    0.0   440.000000
# 2015-02-05 04:05:00    21.000000  24.390000    0.0   444.000000
# 2015-02-05 04:06:00    20.890000  24.390000    0.0   439.500000
# 2015-02-05 04:07:00    20.890000  24.390000    0.0   440.000000
# 2015-02-05 04:08:00    20.890000  24.390000    0.0   440.000000
# 2015-02-05 04:08:59    20.890000  24.290000    0.0   442.000000
# 2015-02-05 04:09:59    20.890000  24.340000    0.0   445.000000
# 2015-02-05 04:11:00    20.856667  24.356667    0.0   447.000000
# 2015-02-05 04:12:00    20.890000  24.390000    0.0   446.000000
# ...

# %%
    oD.plot(y="Humidity",style='.',figsize=(15,1))
    oD.plot(y="CO2",style='.',figsize=(15,1))

# %%
oD.plot(y="Humidity",style='.',figsize=(15,1))

# %%
 oD.plot(y="CO2",style='.',figsize=(15,1))

# %%
oD[["Humidity"]].resample("1h").median().plot(figsize=(15,1))

# %%
oD[["Humidity"]].resample("1d").median().plot(figsize=(15,1))

# %%
oD[["Humidity"]].rolling(60).median().plot(figsize=(15,1))

# %%
oD[["Humidity"]].rolling(60*24).median().plot(figsize=(15,1))

# %%
oD['Year']=oD.index.year
oD['Month']=oD.index.month
oD['Day']=oD.index.day
oD['Hour']=oD.index.hour
oD['Minute']=oD.index.minute
oD['Second']=oD.index.second

# %%
oD.head(10)
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# datetime
# 2015-02-04 17:51:00       23.180   27.2720  426.0  721.250000       0.004793
# 2015-02-04 17:51:59       23.150   27.2675  429.5  714.000000       0.004783
# 2015-02-04 17:53:00       23.150   27.2450  426.0  713.500000       0.004779
# 2015-02-04 17:54:00       23.150   27.2000  426.0  708.250000       0.004772
# 2015-02-04 17:55:00       23.100   27.2000  426.0  704.500000       0.004757
# 2015-02-04 17:55:59       23.100   27.2000  419.0  701.000000       0.004757
# 2015-02-04 17:57:00       23.100   27.2000  419.0  701.666667       0.004757
# 2015-02-04 17:57:59       23.100   27.2000  419.0  699.000000       0.004757
# 2015-02-04 17:58:59       23.100   27.2000  419.0  689.333333       0.004757
# 2015-02-04 18:00:00       23.075   27.1750  419.0  688.000000       0.004745
#
#                      Occupancy  Year  Month  Day  Hour  Minute  Second
# datetime
# ...

# %%
xmasDay=pd.datetime(2014,12,25)

# %%
xmasDay
# Out:
# datetime.datetime(2014, 12, 25, 0, 0)

# %%
boxingDay=xmasDay+pd.DateOffset(days=1)

# %%
boxingDay
# Out:
# Timestamp('2014-12-26 00:00:00')

# %%
today=pd.datetime.now()

# %%
today
# Out:
# datetime.datetime(2019, 12, 11, 18, 3, 2, 842905)

# %%
today+pd.DateOffset(weeks=1)
# Out:
# Timestamp('2019-12-18 18:03:02.842905')

# %%
today+2*pd.DateOffset(years=2, months=6)
# Out:
# Timestamp('2024-12-11 18:03:02.842905')

# %%
lastDay=pd.datetime(2013,12,31)

# %%
lastDay
# Out:
# datetime.datetime(2013, 12, 31, 0, 0)

# %%
from pandas.tseries.offsets import QuarterBegin

# %%
dtoffset=QuarterBegin()
lastDay+dtoffset
# Out:
# Timestamp('2014-03-01 00:00:00')

# %%
dtoffset.rollforward(lastDay)
# Out:
# Timestamp('2014-03-01 00:00:00')

# %%
import datetime

# %%
weekDelta=datetime.timedelta(weeks=1)

# %%
weekDelta
# Out:
# datetime.timedelta(days=7)

# %%
today+weekDelta
# Out:
# datetime.datetime(2019, 12, 18, 18, 3, 2, 842905)
